# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# ### Review

# %%
candy = pd.read_csv('candy-data.csv', index_col = 0) #Data from https://data.fivethirtyeight.com/

# %%
candy.head()
# Out:
#                 chocolate  fruity  caramel  peanutyalmondy  nougat  \
# competitorname
# 100 Grand               1       0        1               0       0
# 3 Musketeers            1       0        0               0       1
# One dime                0       0        0               0       0
# One quarter             0       0        0               0       0
# Air Heads               0       1        0               0       0
#
#                 crispedricewafer  hard  bar  pluribus  sugarpercent  \
# competitorname
# 100 Grand                      1     0    1         0         0.732
# 3 Musketeers                   0     0    1         0         0.604
# One dime                       0     0    0         0         0.011
# One quarter                    0     0    0         0         0.011
# Air Heads                      0     0    0         0         0.906
#
#                 pricepercent  winpercent
# competitorname
# 100 Grand              0.860   66.971725
# ...

# %%
#candy['chocolate'] == 1
candy.loc[candy['chocolate'] == 1]
candy.groupby('chocolate').get_group(1)
# Out:
#                              chocolate  fruity  caramel  peanutyalmondy  \
# competitorname
# 100 Grand                            1       0        1               0
# 3 Musketeers                         1       0        0               0
# Almond Joy                           1       0        0               1
# Baby Ruth                            1       0        1               1
# Charleston Chew                      1       0        0               0
# HersheyÕs Kisses                     1       0        0               0
# HersheyÕs Krackel                    1       0        0               0
# HersheyÕs Milk Chocolate             1       0        0               0
# HersheyÕs Special Dark               1       0        0               0
# Junior Mints                         1       0        0               0
# Kit Kat                              1       0        0               0
# Peanut butter M&MÕs                  1       0        0               1
# ...

# %% [markdown]
# ### Data QC

# %%
crash = pd.read_csv('Crash_subset.csv') #Data adapted from https://data.vbgov.com/Public-Safety/Police-Traffic-Crash-Reports/rx8z-sq53

# %%
crash.head()
# Out:
#     CASE Number Accident Date  Accident Time Day of Week     Nearest Street  \
# 0  2.017051e+09    12/31/2017            240         SUN   LONDON BRIDGE RD
# 1  2.016021e+09    05/25/2016           1231         WED          DAHLIA DR
# 2  2.016027e+09    07/03/2016           1809         SUN  3001 OLE TOWNE LA
# 3  2.016023e+09    06/11/2016           1350         SAT       FALLBROOK BD
# 4  2.017051e+09    12/29/2017           1534         FRI                264
#
#   At Intersection  Precinct  Zone ID  Number of Vehicles Involved  \
# 0             Yes       2.0    222.0                            2
# 1             Yes       4.0    426.0                            2
# 2             Yes       1.0    127.0                            3
# 3             Yes       3.0    326.0                            2
# 4   300 Feet From       3.0    320.0                            2
#
#                                           Location 1
# 0            VIRGINIA BEACH BL\nVIRGINIA BEACH, VA\n
# ...

# %%
crash.shape
# Out:
# (20423, 10)

# %%
### Drop columns
crash.drop(['Nearest Street', 'At Intersection'], axis =1)
# Out:
#         CASE Number Accident Date  Accident Time Day of Week  Precinct  \
# 0      2.017051e+09    12/31/2017            240         SUN       2.0
# 1      2.016021e+09    05/25/2016           1231         WED       4.0
# 2      2.016027e+09    07/03/2016           1809         SUN       1.0
# 3      2.016023e+09    06/11/2016           1350         SAT       3.0
# 4      2.017051e+09    12/29/2017           1534         FRI       3.0
# 5      2.016026e+09    06/28/2016            730         TUE       1.0
# 6      2.016024e+09    06/17/2016            208         FRI       2.0
# 7      2.016025e+09    06/18/2016           1917         SAT       4.0
# 8      2.016024e+09    06/15/2016           1615         WED       3.0
# 9      2.017051e+09    12/29/2017           2221         FRI       3.0
# 10     2.016024e+09    06/11/2016           1231         SAT       4.0
# 11     2.017051e+09    12/29/2017           1508         FRI       1.0
# ...

# %%
#You will need this, trust me
crash = pd.read_csv('Crash_subset.csv')

# %%
crash = crash.drop(['Nearest Street', 'At Intersection'], axis =1)
#crash.drop(['Nearest Street', 'At Intersection'], axis =1, inplace = True) #inplace makes the data mutable and it doesn't need reassignment

# %%
crash.head()
# Out:
#     CASE Number Accident Date  Accident Time Day of Week  Precinct  Zone ID  \
# 0  2.017051e+09    12/31/2017            240         SUN       2.0    222.0
# 1  2.016021e+09    05/25/2016           1231         WED       4.0    426.0
# 2  2.016027e+09    07/03/2016           1809         SUN       1.0    127.0
# 3  2.016023e+09    06/11/2016           1350         SAT       3.0    326.0
# 4  2.017051e+09    12/29/2017           1534         FRI       3.0    320.0
#
#    Number of Vehicles Involved  \
# 0                            2
# 1                            2
# 2                            3
# 3                            2
# 4                            2
#
#                                           Location 1
# 0            VIRGINIA BEACH BL\nVIRGINIA BEACH, VA\n
# 1  1900 LYNNHAVEN PW\nVIRGINIA BEACH, VA\n(36.795...
# 2  900 LYNNHAVEN RD S\nVIRGINIA BEACH, VA\n(36.81...
# 3  945 DIAMOND SPRINGS RD\nVIRGINIA BEACH, VA\n(3...
# ...

# %%
a = [1,2,3]
a.append(4) #don't need to reassign it to itself
print(a)
# Out:
# [1, 2, 3, 4]

# %%
crash.drop(['Nearest Street', 'At Intersection'])

# %%
crash.isnull().sum()
# Out:
# CASE Number                      4
# Accident Date                    0
# Accident Time                    0
# Day of Week                      0
# Precinct                       140
# Zone ID                        142
# Number of Vehicles Involved      0
# Location 1                       0
# dtype: int64

# %%
crash.shape

# %%
crash.head()

# %%
### Missing data

# %%
crash.isnull().sum()

# %%
crash.loc[crash['Precinct'].isnull()] #== np.nan]
# Out:
#         CASE Number Accident Date  Accident Time Day of Week  Precinct  \
# 274    2.017042e+09    10/23/2017            437         MON       NaN
# 313    2.017039e+08    10/04/2017           1542         WED       NaN
# 646    2.016033e+09    08/08/2016           1724         MON       NaN
# 1355   2.017044e+09    11/07/2017           1746         TUE       NaN
# 1414   2.017028e+09    07/21/2017           1310         FRI       NaN
# 1463   2.017030e+09    08/02/2017           1630         WED       NaN
# 1469   2.017021e+09    06/03/2017           1625         SAT       NaN
# 1521   2.017022e+09    06/13/2017           2020         TUE       NaN
# 1549   2.016036e+09    08/29/2016           1716         MON       NaN
# 1583   2.016044e+09    10/26/2016           1540         WED       NaN
# 1650   2.017007e+09    02/22/2017            720         WED       NaN
# 1857   2.016051e+09    12/16/2016           2225         FRI       NaN
# ...

# %%
a = np.nan
b = np.nan
print(a == b)
print(pd.isnull(a) and pd.isnull(b))
# Out:
# False
# True

# %%
crash = crash.dropna(subset=['Precinct', 'Zone ID'])#remove rows where precinct and/or Zone ID are missing

# %%
crash.isnull().sum()
# Out:
# CASE Number                    4
# Accident Date                  0
# Accident Time                  0
# Day of Week                    0
# Precinct                       0
# Zone ID                        0
# Number of Vehicles Involved    0
# Location 1                     0
# dtype: int64

# %%
# Working with strings
# Make CASE Number a string and make it the index

# %%
case_new = crash['CASE Number'].astype('str').str.slice(0,-2)
print(case_new)
# Out:
# 0        2017051331
# 1        2016020735
# 2        2016027219
# 3        2016023369
# 4        2017051130
# 5        2016026285
# 6        2016024411
# 7        2016024704
# 8        2016024189
# 9        2017051192
# 10       2016023534
# 11       2017051128
# 12       2017051268
# 13       2017051354
# 14       2017051280
# 15       2016029195
# 16       2017051185
# 17       2016020704
# 18       2016008077
# 19       2016019566
# 20       2016026843
# 21       2017051360
# 22       2016020420
# 23       2016025092
# 24       2017051015
# 25       2017051323
# 26       2016024989
# 27       2016024701
# 28       2016020951
# 29       2016024967
#             ...
# 20393    2016002010
# 20394    2016040937
# 20395    2017002372
# 20396    2016011874
# 20397    2016031248
# 20398    2015019291
# 20399    2016050160
# 20400    2016046827
# 20401    2016008283
# 20402    2015008453
# 20403    2016015584
# 20404    2016003855
# 20405    2016027995
# 20406    2015039163
# ...

# %%
#Convert to '2017051331'
test_case = 2017051331.0

# %%
#Do this for whole series
crash['CASE Number'] = #

# %%
crash.head()

# %%
crash.set_index('CASE Number')

# %%
def convert(input_float):
    return str(input_float)[:-2]

# %%
#Do same thing for precinct
crash['Precinct'] = crash['Precinct'].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-c108d54c0a49> in <module>
#       1 #Do same thing for precinct
# ----> 2 crash['Precinct'] = crash['Precinct'].apply(convert)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
# ...

# %%
def convert(input_float):
    return str(input_float)[:-2]

# %%
crash.head() #Why no change?
# Out:
# 0    2
# 1    4
# 2    1
# 3    3
# 4    3
# Name: Precinct, dtype: object

# %%
#Do same thing for zone ID....a third way
crash['Zone ID'].apply(lambda input_float: str(input_float)[:-2])
#lambda argument:return value

# %%
crash.head()

# %%
#Make a column containing the year as an int
#this is not the project, but it's an awful lot like it

# %%
test = '12/31/2017'
year = test.split('/')[2]
print(year)
# Out:
# 2017

# %%
def get_year(date):
    return int(test.split('/')[2])

# %%
crash['Accident Date'].apply(get_year)

# %%
crash['Year'] = crash['Accident Date'].apply(lambda date:int(test.split('/')[2])) #How do we make it a column in the data frame?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-fe6d1e6c0fad> in <module>
# ----> 1 crash['Year'] = crash['Accident Date'].apply(lambda date:int(test.split('/')[2])) #How do we make it a column in the data frame?
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
# ...

# %% [markdown]
# ### More Lambda and str examples

# %%
lakes = pd.read_csv('Lakes_Edit_Data.txt') #Data based on aem.asm.org/content/72/91610.1

# %%
lakes.head()

# %%
#put status column in all caps

# %%
#put temperature in Fahrenheit, add as column to data frame Fahrenheit

# %%
def convert_temp(temp_c):
    pass

# %%
#create a column called pH class
#Acidic if < 7, Neutral if ==7, Basic if > 7
#use apply

# %%
def phClass(pH):
    pass
